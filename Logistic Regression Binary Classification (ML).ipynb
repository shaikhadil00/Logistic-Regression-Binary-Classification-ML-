# %% [markdown]
# ![Screenshot%202024-03-09%20123749.png](attachment:Screenshot%202024-03-09%20123749.png)

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("csv .Insurance.csv")

# %%
df
# Out:
#     SR NO.  Age  Insurance
# 0        0   18          0
# 1        1   20          0
# 2        2   25          0
# 3        3   23          0
# 4        4   19          0
# 5        5   26          0
# 6        6   29          0
# 7        7   35          1
# 8        8   42          1
# 9        9   32          1
# 10      10   43          1
# 11      11   55          1
# 12      12   60          1
# 13      13   30          0
# 14      14   28          0
# 15      15   31          0
# 16      16   56          1
# 17      17   69          1
# 18      18   90          1
# 19      19   85          1
# 20      20   64          1
# 21      21   78          1
# 22      22   99          1
# 23      23  110          1
# 24      24   49          1
# 25      25   20          0
# 26      26   18          0
# 27      27   25          0
# 28      28   28          0
# 29      29   22          0

# %%
plt.scatter(df.Age,df.Insurance)
plt.scatter(df.Age,df.Insurance, color ="b" , marker = "D")

# %% [markdown]
#  There different marker also use few for EX :- 'o' circle , 's' square , '^' triangle , 'x' crosses , 'D' daimond ETC

# %%
df.shape
# Out:
# (30, 3)

# %%
#training and testing data 
from sklearn.model_selection import train_test_split

# %%
#train_test_split(df[['Age']],df.Insurance,test_size = 0.2)
x_train,x_test,y_train,y_test = train_test_split(df[['Age']],df.Insurance,test_size = 0.2)

# %%
x_train
# Out:
#     Age
# 18   90
# 28   28
# 29   22
# 11   55
# 16   56
# 27   25
# 6    29
# 5    26
# 20   64
# 21   78
# 3    23
# 13   30
# 14   28
# 26   18
# 23  110
# 24   49
# 0    18
# 22   99
# 15   31
# 8    42
# 12   60
# 17   69
# 25   20
# 10   43

# %%
y_train
# Out:
# 18    1
# 28    0
# 29    0
# 11    1
# 16    1
# 27    0
# 6     0
# 5     0
# 20    1
# 21    1
# 3     0
# 13    0
# 14    0
# 26    0
# 23    1
# 24    1
# 0     0
# 22    1
# 15    0
# 8     1
# 12    1
# 17    1
# 25    0
# 10    1
# Name: Insurance, dtype: int64

# %%
x_test
# Out:
#     Age
# 7    35
# 2    25
# 1    20
# 19   85
# 4    19
# 9    32

# %%
y_test
# Out:
# 7     1
# 2     0
# 1     0
# 19    1
# 4     0
# 9     1
# Name: Insurance, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#For Predicting
model.predict(x_test)
# Out:
# array([0, 0, 0, 1, 0, 0], dtype=int64)

# %%
model.score(x_test,y_test)
# Out:
# 0.6666666666666666

# %%
model.predict_proba(x_test)
# Out:
# array([[7.58311758e-01, 2.41688242e-01],
#        [9.99492970e-01, 5.07029874e-04],
#        [9.99979762e-01, 2.02380214e-05],
#        [3.19744231e-14, 1.00000000e+00],
#        [9.99989374e-01, 1.06256824e-05],
#        [9.55906267e-01, 4.40937326e-02]])

# %% [markdown]
# # 1st colomn represent it will not take Insurance according to %

# %% [markdown]
# # 2nd colomn represent it will take Insurance according to %

# %% [markdown]
# # array([0, 0, 0, 1, 0, 0], dtype=int64)

# %% [markdown]
# # The above answer represent the binary classification prediction i.e 0 , 1

# %% [markdown]
# # hence we conclude
